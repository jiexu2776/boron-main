# %%
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np
import warnings
import statistics as stt
import bamboolib as bam
from brokenaxes import brokenaxes
import os
import plotly.express as px

# %%
dfCa = pd.read_csv('Ca corrected results.csv')
dfSi = pd.read_csv('Si corrected results.csv')
dfNa = pd.read_csv('Na corrected results.csv')
dfAl = pd.read_csv('Al corrected results.csv')
dfChondrites = pd.read_excel("chondrite element abundances.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/7h/d1qc3x117419gw0q21cgm7z00000gn/T/ipykernel_58410/3562409372.py in <module>
# ----> 1 dfCa = pd.read_csv('Ca corrected results.csv')
#       2 dfSi = pd.read_csv('Si corrected results.csv')
#       3 dfNa = pd.read_csv('Na corrected results.csv')
#       4 dfAl = pd.read_csv('Al corrected results.csv')
#       5 dfChondrites = pd.read_excel("chondrite element abundances.xlsx")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
dfCa.columns

# %%
ree = ['La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu']
spiderree = ['Cs', 'Rb', 'Ba', 'Th', 'U', 'Nb', 'Ta', 'La', 'Ce', 'Pb', 'Pr', 'B', 'Nd', 'Sr', 'Sm', 'Zr', 'Hf', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Y', 'Tm', 'Yb', 'Li', 'Lu']

cIValues = dfChondrites.iloc[56:71, 5].tolist()
cIValues.pop(4)  # removes Pm

cIValuesspider = dfChondrites.iloc[91:119, 2].tolist()



def plotREE(normalised, sample):
    
    #fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 10))
    #ax1 = plt.subplot(2, 2, 1)
    #ax2 = plt.subplot(2, 2, 2)
    #global data
    
    if normalised == True:
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 10))
        ax1 = plt.subplot(2, 2, 1)
        ax2 = plt.subplot(2, 2, 2)
        fil = dfmillingball['Analysis'] == sample
        dfdree = dfmillingball.loc[fil, ree]
        dfdspider = dfmillingball.loc[fil, spiderree]
        reeres = dfdree.astype(float)/cIValues
        spiderres = dfdspider.astype(float)/cIValuesspider
        
        ax1.plot(reeres.T)
        ax1.set_yscale('log')
        ax1.set_ylim(0.1,100000)

        ax2.plot(spiderres.T)
        ax2.set_yscale('log')
        ax2.set_ylim(0.01,100000)
        ax1.set_ylabel('sample / Primitive mantle')
        ax2.set_ylabel('sample / Primitive mantle')

        
    else:
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 10))
        ax1 = plt.subplot(2, 2, 1)
        ax2 = plt.subplot(2, 2, 2)
        fil = dfmillingball['Analysis'] == sample
        
        dfdree = dfmillingball.loc[fil, ree]
        dfdspider = dfmillingball.loc[fil, spiderree]
        reeres = dfdree.astype(float)
        spiderres = dfdspider.astype(float)
        
        ax1.plot(reeres.T)
        ax1.set_yscale('log')
        ax1.set_ylim(0.0001,10000)

        ax2.plot(spiderres.T)
        ax2.set_yscale('log')
        ax2.set_ylim(0.0001,10000)
        ax1.set_ylabel('sample')
        ax2.set_ylabel('sample')

 
    return plt.show()

# %%
samples = dfmillingball['Analysis'].drop_duplicates()
interact(plotREE, normalised = True, sample = samples)
