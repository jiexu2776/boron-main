# %% [markdown]
# <h1> B Data Reduction </h1>

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np
import warnings
import statistics as stt
#import bamboolib as bam
#from brokenaxes import brokenaxes
import os
from scipy import stats
from scipy.optimize import curve_fit
from numpy import arange
from collections import deque
import string

# %% [markdown]
# # Functions to calculate averages of one measurement point

# %%
#Functions to calculate averages of one measurement point


#-------------------------------
# Loading & select different type of data, z.b B, C, U
#-------------------------------

def dirFiles(fDir, ending):
    fNames = []
    for i in os.listdir(fDir):
        if i.endswith(ending):
            fNames.append(i)
    return fNames

def selSmpType(dataFiles, smp):
    l = []
    for file in dataFiles:    
        if smp in file.split('_')[1]:
            l.append(file)
    return l


#-------------------------------
# read the number from Neptune filename
#-------------------------------

def getfilenumber(datafile, simbel):
    res = []
    for i in datafile:
        res.append(float(i.split(simbel)[0]))
    return res


#-------------------------------
# Outlier Correction and Data Conversion from str to float
#-------------------------------
def outlierCorrection(measurement, factorSD):
    element_signal = np.array(measurement)
    mean = np.mean(element_signal, axis=0)
    sd = np.std(element_signal, axis=0)
    return [x for x in measurement if (x > mean - factorSD * sd) and (x < mean + factorSD * sd)]


def data_convert(data):
    data_float = []
    fil =  (data.str.contains('L|IC|C|H') == True)
    endnum = data[fil].index[0]
    for i in data[0:endnum]:
        data_float.append(float(i))
    return data_float


#-------------------------------
#background substact with the basic method, signal_aver-background_aver
#-------------------------------

def background_substract_basic(filename, signal_object, select_line, factorSD):
#upload data:
    df = pd.read_csv('data/2022-11-04 Boron measurements/' + filename, sep='\t', header=22)  # Hi Jie, I already inserted the additional argument here
#calculate average signal and average backgroud:

    data_float = data_convert(df[signal_object]) #conversion to float required, as numbers are stored as str
    fils = []
    filw = []
        
    for i in data_float:
        if (i > select_line) == True:
            fils.append(i)
        else:
            filw.append(i)

    signal_aver = np.mean(outlierCorrection(fils, factorSD))
    backg_aver = np.mean(outlierCorrection(filw, factorSD))
    res = signal_aver - backg_aver
    return(res)


#-------------------------------
# background substact for 10B with the average of 9.9 and 10.2, think abut each line has to be connected
#-------------------------------


def background_substract_interference_bacground(filename, select_line, factorSD, factor_B11):
    
    df = pd.read_csv('data/2022-11-04 Boron measurements/' + filename, sep='\t', header=22)  # Hi Jie, I already inserted the additional argument here
    res_bacg_inter_sub = []
    data_interference_left = data_convert(df['9.9'])
    data_interference_right = data_convert(df['10.2'])
    data_B10 = data_convert(df['10B'])
    data_B11 = data_convert(df['11B'])

    bacgrounds = []
    bacgrounds_10 = []
    bacgrounds_11 = []
    for i in data_B10:
        if (i < select_line) == True:
            index = data_B10.index(i)
            j = data_B11[index]
            bacgrounds_10.append(i)
            bacgrounds_11.append(j)
    backg10_aver = np.mean(outlierCorrection(bacgrounds_10, factorSD))        
    backg11_aver = np.mean(outlierCorrection(bacgrounds_11, factorSD))        


    for i in data_B10:
        if (i > select_line) == True:
            index = data_convert(df['10B']).index(i)
            interference = (data_interference_left[index] + data_interference_right[index])/2
            res_10 = i - interference - backg10_aver
            res_11 = data_B11[index] - (interference * factor_B11) - backg11_aver
            res_bacg_inter_sub.append (res_11/res_10)

    res = outlierCorrection(res_bacg_inter_sub, factorSD)
    return np.mean(res)

#-------------------------------
# average valye calculation
#-------------------------------
def calculate_aver(dataFiles, IC):
    res = []
    for i in dataFiles:
        if IC == True:
            aver = calculateSingleFile_B11(i, 0.005, 2)/calculateSingleFile_B10_IC(i, 0.0005, 2)
        else:
            aver = calculateSingleFile_B11(i, 0.005, 2)/calculateSingleFile_B10_FC(i, 0.0005, 2)
        Neptune_res = {'sequence': i, 'average':aver}
        res.append(Neptune_res)
        df = pd.DataFrame(res)
        
    return df

#-------------------------------
# regression based on the level from 2-5 you chosed
#-------------------------------

def polynomFit(inp, *args):
    x=inp
    res=0
    for order in range(len(args)):
        res+=args[order] * x**order
    return res


def regression(x, y, order):
    fig, ax = plt.subplots()
    ax.plot(x, y, label='measuered', marker='o', linestyle='none' )
    x_use = np.array(x)
    popt, pcov = curve_fit(polynomFit, xdata=x_use, ydata=y , p0=[0]*(order+1))
    fitData=polynomFit(x_use,*popt)
    ax.plot(x_use, fitData, label='polyn. fit, order '+str(order), linestyle='--' )
    ax.legend( loc='upper left', bbox_to_anchor=(1.05, 1))

# %% [markdown]
# #  load all .exp files and Calculate averages

# %%
dataFiles = dirFiles('data/2022-11-04 Boron measurements', 'exp')
dataFiles.sort()

dataFiles_A = selSmpType(dataFiles, 'A')

dataFiles_BCDU = [i for i in dataFiles if i not in dataFiles_A]

calculate_aver(dataFiles_BCDU, IC=False)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#       sequence   average
# 0    003_B.exp  7.996016
# 1    004_B.exp  7.997860
# 2    005_C.exp  8.005130
# 3    006_C.exp  8.017459
# 4    007_D.exp  6.562499
# ..         ...       ...
# 410  429_U.exp  7.908942
# 411  430_U.exp  7.863624
# 412  431_U.exp  7.861890
# 413  432_U.exp  7.868375
# 414  433_U.exp  7.777447
#
# [415 rows x 2 columns]

# %% [markdown]
# # Use A get the regression line

# %%
y = calculate_aver(dataFiles_A, IC=False)['average'][2:]
x = getfilenumber(dataFiles_A, '_')[2:]

regression(x,y,2)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
def offset_calculation(datafile):
    res = []
    a = deque(drift_corrected)
    a.rotate(1)
    y=0
    for k in datafile:
        for i in range(len(a)):
            res = a[i]*(k**i)
            y = res + y
        return y
    res.append(y)
offset_calculation([59, 60, 99])

# %%
offset_datafile = getfilenumber(dataFiles_BCDU, '_')
offset_calculation(offset_datafile)

# %% [markdown]
# # # #sign the regression value to samples

# %%
dataFiles = dirFiles('data/2022-11-04 Boron measurements', 'exp')
dataFiles.sort()

dataFiles = selSmpType('B')

dataFiles

res = []
for i in dataFiles:
    aver = background_substract_basic(i, '11B', 0.005, 2)/background_substract_basic(i, '10B', 0.0005, 2)
    Neptune_res = {'sequence': i, 'average':aver}
    res.append(Neptune_res)

x_b = getfilenumber(pd.DataFrame(res)['sequence'], '_')

#def offset(datafile):
 #   res = []
  #  for i in datafile:
   #     res.append(objective(i, a, b, c, d, e, f))
    #return res

#offset(x_b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7h/d1qc3x117419gw0q21cgm7z00000gn/T/ipykernel_74143/3102392654.py in <module>
#       2 dataFiles.sort()
#       3
# ----> 4 dataFiles = selSmpType('B')
#       5
#       6 dataFiles
#
# TypeError: selSmpType() missing 1 required positional argument: 'smp'

# %%
res = []
for i in dataFiles:
    aver = background_substract_basic(i, '11B', 0.005, 2)/background_substract_basic(i, '10B', 0.0005, 2)
    Neptune_res = {'sequence': i, 'average':aver}
    res.append(Neptune_res)
res
# Out:
# [{'sequence': '001_A.exp', 'average': nan},
#  {'sequence': '002_A.exp', 'average': nan},
#  {'sequence': '003_B.exp', 'average': 7.914217372689466},
#  {'sequence': '004_B.exp', 'average': 7.916079660065434},
#  {'sequence': '005_C.exp', 'average': 7.920352270470259},
#  {'sequence': '006_C.exp', 'average': 7.795858242951819},
#  {'sequence': '007_D.exp', 'average': 6.577708938130702},
#  {'sequence': '008_D.exp', 'average': 6.668162723003221},
#  {'sequence': '009_U.exp', 'average': 7.577444241836286},
#  {'sequence': '010_U.exp', 'average': 7.100753176282168},
#  {'sequence': '011_U.exp', 'average': 7.385885456972999},
#  {'sequence': '012_U.exp', 'average': 7.63303257897614},
#  {'sequence': '013_U.exp', 'average': 7.2634329499343515},
#  {'sequence': '014_U.exp', 'average': nan},
#  {'sequence': '015_U.exp', 'average': 7.117365344763357},
#  {'sequence': '016_U.exp', 'average': 6.585539296987043},
#  {'sequence': '017_U.exp', 'average': 6.60801622071004},
#  {'sequence': '018_U.exp', 'average': 6.647809503181595},
#  {'sequence': '019_U.exp', 'average': 6.534961820381849},
#  {'sequence': '020_U.exp', 'average': 7.654491702264361},
#  {'sequence': '021_U.exp', 'average': 7.9416460304762335},
#  {'sequence': '022_U.exp', 'average': 7.902794491773513},
#  {'sequence': '023_U.exp', 'average': 7.825598133647636},
#  {'sequence': '024_U.exp', 'average': 7.904849445989103},
#  {'sequence': '025_U.exp', 'average': 7.915630190587601},
#  {'sequence': '026_U.exp', 'average': 7.701539707336134},
#  {'sequence': '027_U.exp', 'average': 7.789129450148799},
#  {'sequence': '028_U.exp', 'average': 7.6541925645220665},
#  {'sequence': '029_U.exp', 'average': 7.8230640633557895},
#  {'sequence': '030_U.exp', 'average': 7.805199847247984},
#  {'sequence': '031_U.exp', 'average': 7.848149617891542},
#  {'sequence': '032_U.exp', 'average': 7.816604721059301},
#  {'sequence': '033_U.exp', 'average': 7.964436583544703},
#  {'sequence': '034_U.exp', 'average': 7.933300454484194},
#  {'sequence': '035_U.exp', 'average': 7.809917209050205},
#  {'sequence': '036_U.exp', 'average': 7.885992591940679},
#  {'sequence': '037_U.exp', 'average': 7.840895845329181},
#  {'sequence': '038_U.exp', 'average': 7.814105817032973},
#  {'sequence': '039_U.exp', 'average': 7.941570425840361},
#  {'sequence': '040_U.exp', 'average': 7.6882495790689},
#  {'sequence': '041_U.exp', 'average': 7.668653516963358},
#  {'sequence': '042_U.exp', 'average': 7.5978637630852806},
#  {'sequence': '043_U.exp', 'average': 7.245510193747995},
#  {'sequence': '044_U.exp', 'average': 7.652512539193242},
#  {'sequence': '411_U.exp', 'average': 4.5928067567011235},
#  {'sequence': '412_U.exp', 'average': 4.594506415010109},
#  {'sequence': '413_U.exp', 'average': 4.595587019556641},
#  {'sequence': '414_U.exp', 'average': 4.622435881297056},
#  {'sequence': '415_U.exp', 'average': 4.590617705332795},
#  {'sequence': '416_U.exp', 'average': 4.592717122119035},
#  {'sequence': '417_U.exp', 'average': 4.621720489318007},
#  {'sequence': '418_U.exp', 'average': 4.625681151197839},
#  {'sequence': '419_U.exp', 'average': 4.567533652715448},
#  {'sequence': '420_U.exp', 'average': 4.565991830097091},
#  {'sequence': '421_U.exp', 'average': 4.590546987045381},
#  {'sequence': '422_U.exp', 'average': 4.656796069045712},
#  {'sequence': '423_U.exp', 'average': 4.591286995522787},
#  {'sequence': '424_U.exp', 'average': 4.621226452763094},
#  {'sequence': '425_U.exp', 'average': 4.568177406261185},
#  {'sequence': '426_U.exp', 'average': 4.567742982871877},
#  {'sequence': '427_U.exp', 'average': 4.59154645837474},
#  {'sequence': '428_U.exp', 'average': 4.6235973002822846},
#  {'sequence': '429_U.exp', 'average': 4.599313780612468},
#  {'sequence': '430_U.exp', 'average': 4.573970088841021},
#  {'sequence': '431_U.exp', 'average': 4.540764704605732},
#  {'sequence': '432_U.exp', 'average': 4.5574766650008645},
#  {'sequence': '433_U.exp', 'average': 4.515517633650046}]

# %% [markdown]
# # Laser log file

# %%
df_Laser = pd.read_csv('data/Seq_log_20221104_191152.csv', header=0)
Laser_sequece = df_Laser[' Sequence Number'].dropna()
res_laser = []
dfN = pd.DataFrame(res)

for i in dfN['sequence']:
    Nep_index = float(i.split('_')[0])
    mapping = Laser_sequece[Laser_sequece==Nep_index].index[0]
    
    res_laser.append([i, df_Laser.loc[mapping, ' Laser Energy (mJ)'], df_Laser.loc[mapping, ' Spot Size (um)'], 
                      df_Laser.loc[mapping, ' Laser HV (kV)']])
pd.DataFrame(res_laser).rename(columns = {0:'Sample Name', 1: ' Laser Energy (mJ)', 2: ' Spot Size (um)', 3: ' Laser HV (kV)'})
# Out:
#    Sample Name   Laser Energy (mJ)  Spot Size (um)   Laser HV (kV)
# 0    001_A.exp              63.920            23.0          22.970
# 1    002_A.exp              65.034     60.0 x 60.0          23.243
# 2    051_A.exp              65.310   108.0 x 108.0          23.125
# 3    052_A.exp              65.225     60.0 x 60.0          23.308
# 4    101_A.exp              65.023   108.0 x 108.0          23.291
# 5    102_A.exp              64.606     60.0 x 60.0          23.540
# 6    151_A.exp              64.728   108.0 x 108.0          23.320
# 7    152_A.exp              65.286     60.0 x 60.0          23.296
# 8    201_A.exp              65.198   160.0 x 160.0          23.213
# 9    202_A.exp              65.121     60.0 x 60.0          23.321
# 10   251_A.exp              65.264   160.0 x 160.0          23.320
# 11   252_A.exp              65.088     60.0 x 60.0          23.296
# 12   301_A.exp              65.283     60.0 x 60.0          23.381
# 13   302_A.exp              65.341     60.0 x 60.0          23.348
# 14   351_A.exp              64.781   108.0 x 108.0          23.303
# 15   352_A.exp              64.913     60.0 x 60.0          23.343
# 16   401_A.exp              64.836     28.0 x 28.0          23.291
# 17   402_A.exp              65.309     60.0 x 60.0          23.285

# %%
df_Laser
# Out:
#                     Timestamp   Sequence Number   SubPoint Number  \
# 0     2022-11-04 19:11:52.899               1.0               1.0
# 1     2022-11-04 19:11:52.939               NaN               NaN
# 2     2022-11-04 19:12:06.191               NaN               NaN
# 3     2022-11-04 19:12:51.741               NaN               NaN
# 4     2022-11-04 19:13:18.705               NaN               NaN
# ...                       ...               ...               ...
# 2161   2022-11-05 4:06:45.321               NaN               NaN
# 2162   2022-11-05 4:06:45.433               NaN               NaN
# 2163   2022-11-05 4:07:30.441               NaN               NaN
# 2164   2022-11-05 4:07:57.429               NaN               NaN
# 2165   2022-11-05 4:08:13.750               NaN               NaN
#
#        Vertix Number  Comment   X(um)   Y(um)   Intended X(um)  \
# 0                NaN     nist  140752   63216              NaN
# 1                NaN      NaN  140323   63315              NaN
# 2                NaN      NaN   12015   93101     12015.479492
# 3                NaN      NaN   12015   93101              NaN
# 4                NaN      NaN   12015   93101              NaN
# ...              ...      ...     ...     ...              ...
# 2161             NaN      NaN   12524   92801              NaN
# 2162             NaN      NaN   12524   92801     12524.419922
# 2163             NaN      NaN   12524   92801              NaN
# 2164             NaN      NaN   12524   92801              NaN
# 2165             NaN      NaN   12524   92801              NaN
#
#        Intended Y(um)   Scan Velocity (um/s)  ...  Spot Size (um)  \
# 0                 NaN                    NaN  ...            23.0
# 1                 NaN                10000.0  ...            23.0
# 2        93101.218750                    NaN  ...            23.0
# 3                 NaN                    NaN  ...     60.0 x 60.0
# 4                 NaN                    NaN  ...     60.0 x 60.0
# ...               ...                    ...  ...             ...
# 2161              NaN                10000.0  ...     60.0 x 60.0
# 2162     92800.632812                    NaN  ...     60.0 x 60.0
# 2163              NaN                    NaN  ...     60.0 x 60.0
# 2164              NaN                    NaN  ...     60.0 x 60.0
# 2165              NaN                    NaN  ...     60.0 x 60.0
#
#        Spot Angle (deg)  MFC1 (ml/min)  MFC2 (ml/min)   Cell Pressure (kPa)  \
# 0                     0     348.791281       6.024414              8.038547
# 1                     0     348.791281       6.024414              8.038547
# 2                     0     351.118788       5.897461              7.282579
# 3                     0     344.433396       5.989258              6.737290
# 4                     0     344.879088       5.953125              6.786862
# ...                 ...            ...            ...                   ...
# 2161                  0     345.968560       5.908203              6.786862
# 2162                  0     345.621910       5.915039              6.811647
# 2163                  0     343.789617       5.925781              6.824040
# 2164                  0     343.591531       5.899414              7.047113
# 2165                  0      -9.694314       1.286133              3.168127
#
#        Z(um)      Laser Mode   Laser HV (kV)   Laser Energy (mJ)  \
# 0          0  Compex_EGY_NGR          22.970              63.920
# 1          0  Compex_EGY_NGR          22.970              63.920
# 2          0  Compex_EGY_NGR          22.970              63.920
# 3          0  Compex_EGY_NGR          22.960              64.600
# 4          0  Compex_EGY_NGR          23.241              65.038
# ...      ...             ...             ...                 ...
# 2161       0  Compex_EGY_NGR          23.319              65.299
# 2162       0  Compex_EGY_NGR          23.319              65.299
# 2163       0  Compex_EGY_NGR          23.170              65.820
# 2164       0  Compex_EGY_NGR          23.356              64.956
# 2165       0  Compex_EGY_NGR          23.340              64.740
#
#       On-Sample Fluence (J.cm⁻²)
# 0                          2.809
# 1                          2.809
# 2                          2.809
# 3                          2.883
# 4                          2.783
# ...                          ...
# 2161                       2.856
# 2162                       2.856
# 2163                       2.923
# 2164                       2.811
# 2165                       2.786
#
# [2166 rows x 23 columns]

# %% [markdown]
# # Testing

# %%
results = {'Laser Energy (mJ)': res_energy, 
           'Spot Size (um)': res_spotsize, 'Laser HV (kV)': res_HV}

Laser_res= pd.DataFrame(results)
resss = pd.concat([Laser_res, dfN.reindex(Laser_res.index)], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7h/d1qc3x117419gw0q21cgm7z00000gn/T/ipykernel_15858/2144661703.py in <module>
# ----> 1 results = {'Laser Energy (mJ)': res_energy,
#       2            'Spot Size (um)': res_spotsize, 'Laser HV (kV)': res_HV}
#       3
#       4 Laser_res= pd.DataFrame(results)
#       5 resss = pd.concat([Laser_res, dfN.reindex(Laser_res.index)], axis=1)
#
# NameError: name 'res_energy' is not defined

# %%
def laser_Cond(smp):
    return resss[resss['sequence'].str.contains(smp)]

laser_Cond('A')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7h/d1qc3x117419gw0q21cgm7z00000gn/T/ipykernel_15858/949883889.py in <module>
#       2     return resss[resss['sequence'].str.contains(smp)]
#       3
# ----> 4 laser_Cond('A')
#
# /var/folders/7h/d1qc3x117419gw0q21cgm7z00000gn/T/ipykernel_15858/949883889.py in laser_Cond(smp)
#       1 def laser_Cond(smp):
# ----> 2     return resss[resss['sequence'].str.contains(smp)]
#       3
#       4 laser_Cond('A')
#
# NameError: name 'resss' is not defined

# %% [markdown]
# ### Some old code

# %%
#check for outliers for signal:
    element_signal = np.array(fils)
    mean = np.mean(element_signal, axis=0)
    sd = np.std(element_signal, axis=0)
    final_list_signal = [x for x in fils if (x > mean - factorSD * sd)]
    final_list_signal = [x for x in final_list_signal if (x < mean + factorSD * sd)]
    
#check for outliers for background:
    element_backg = np.array(filw)
    mean = np.mean(element_backg, axis=0)
    sd = np.std(element_backg, axis=0)
    final_list_backg = [x for x in filw if (x > mean - factorSD * sd)]
    final_list_backg = [x for x in final_list_backg if (x < mean + factorSD * sd)]
    

def calculateSingleFile(filename, bg_10B, factorSD):
#upload data:
    df = pd.read_csv('data/2022-02-15 Boron measurements/' + filename, sep='\t', header=22)  # Hi Jie, I already inserted the additional argument here
#calculate average signal and average backgroud:
    endnum = df['10B'][df['10B'] == 'L3'].index[0]
#    B_10 = []
    fils = []
    filw = []
#    for i in df['10B'][0:endnum]:
#        B_10.append(float(i)) #conversion to float required, as numbers are stored as str
#    for i in B_10:
    for i in df['10B'][0:endnum]:
        meas = float(i)
        if (meas > bg_10B) == True:
            fils.append(meas)
        else:
            filw.append(meas)

#    outlier_corrected_signal =outlierCorrection(fils, factorSD)
#    outlier_corrected_backg =outlierCorrection(filw, factorSD)

#    B_10_aver = sum(outlier_corrected_signal )/len(outlier_corrected_signal )
#    B_10_backg_aver = sum(outlier_corrected_backg)/len(outlier_corrected_backg)

    B_10_aver = np.mean(outlierCorrection(fils, factorSD))
    B_10_backg_aver = np.mean(outlierCorrection(filw, factorSD))
    
    return(B_10_aver, B_10_backg_aver)
